# %%
# %pip install tqdm
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: tqdm in /home/lumiani/miniconda3/envs/cs182/lib/python3.11/site-packages (4.66.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
import os

from NeuralNetwork.CNN import CNN_MEL, CNN_CHR, CNN_MFCC
from NeuralNetwork.CRNN import CRNN_MEL, CRNN_CHR, CRNN_MFCC

warnings.filterwarnings("ignore")
os.environ["CUDA_VISIBLE_DEVICES"] = "1" # keep this, use the second GPU, i'll use the first one
# Out:
# 2024-01-28 15:46:41.398242: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-28 15:46:41.418010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-28 15:46:41.418035: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-28 15:46:41.418602: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-28 15:46:41.422172: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-28 15:46:41.811185: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
try:
    del model_mel
    del model_chr
    del model_mfcc
    print("clean!")
except:
    pass
model_mel = CRNN_MEL((1293,128,1))
model_chr = CNN_CHR((1293,12,1))
model_mfcc = CRNN_MFCC((1293, 20, 1))
# Out:
# 2024-01-28 15:46:42.416432: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.437879: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.437987: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.439027: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1293, 128, 32)     320
#
#  max_pooling2d (MaxPooling2  (None, 646, 64, 32)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 646, 64, 64)       18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 323, 32, 64)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 323, 32, 128)      73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 161, 16, 128)      0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 161, 16, 256)      295168
#
#  batch_normalization (Batch  (None, 161, 16, 256)      1024
#  Normalization)
#
#  time_distributed (TimeDist  (None, 161, 4096)         0
#  ributed)
#
#  lstm (LSTM)                 (None, 256)               4457472
#
#  dense (Dense)               (None, 1024)              263168
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 5639434 (21.51 MB)
# Trainable params: 5638922 (21.51 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# 2024-01-28 15:46:42.439103: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.439154: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.480313: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.480401: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.480461: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-28 15:46:42.480510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20555 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# None
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 1293, 12, 32)      320
#
#  max_pooling2d_3 (MaxPoolin  (None, 646, 6, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 646, 6, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 323, 3, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 323, 3, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 161, 1, 128)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 161, 1, 256)       295168
#
#  batch_normalization_1 (Bat  (None, 161, 1, 256)       1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 161, 1, 256)       0
#
#  flatten_1 (Flatten)         (None, 41216)             0
#
#  dense_3 (Dense)             (None, 1024)              42206208
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 43125002 (164.51 MB)
# Trainable params: 43124490 (164.51 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# None
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 1293, 20, 32)      320
#
#  max_pooling2d_6 (MaxPoolin  (None, 646, 10, 32)       0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 646, 10, 64)       18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 323, 5, 64)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 323, 5, 128)       73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 161, 2, 128)       0
#  g2D)
#
#  layer_normalization (Layer  (None, 161, 2, 128)       256
#  Normalization)
#
#  time_distributed_1 (TimeDi  (None, 161, 256)          0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 256)               525312
#
#  dense_6 (Dense)             (None, 1024)              263168
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1411338 (5.38 MB)
# Trainable params: 1411338 (5.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model_mfcc.train("./dataset/mfcc_format", epoch=200)
model_mel.train("./dataset/mel2_format", epoch=50)
model_chr.train("./dataset/chr_format", epoch=10)
# Out:
# Found 999 images belonging to 10 classes.
# Epoch 1/400
# 2024-01-28 15:46:44.023157: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-01-28 15:46:44.537743: I external/local_xla/xla/service/service.cc:168] XLA service 0xaa5cd70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-28 15:46:44.537762: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-01-28 15:46:44.540726: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706428004.581126 2186388 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50/50 - 3s - loss: 2.5441 - acc: 0.1051 - 3s/epoch - 57ms/step
# Epoch 2/400
# 50/50 - 0s - loss: 2.4841 - acc: 0.0931 - 380ms/epoch - 8ms/step
# Epoch 3/400
# 50/50 - 0s - loss: 2.4633 - acc: 0.1081 - 399ms/epoch - 8ms/step
# Epoch 4/400
# 50/50 - 0s - loss: 2.4203 - acc: 0.1081 - 394ms/epoch - 8ms/step
# Epoch 5/400
# 50/50 - 0s - loss: 2.4367 - acc: 0.1041 - 401ms/epoch - 8ms/step
# Epoch 6/400
# 50/50 - 0s - loss: 2.4354 - acc: 0.0901 - 372ms/epoch - 7ms/step
# Epoch 7/400
# 50/50 - 0s - loss: 2.3864 - acc: 0.1081 - 386ms/epoch - 8ms/step
# Epoch 8/400
# 50/50 - 0s - loss: 2.3980 - acc: 0.0861 - 382ms/epoch - 8ms/step
# Epoch 9/400
# 50/50 - 0s - loss: 2.3569 - acc: 0.0721 - 404ms/epoch - 8ms/step
# Epoch 10/400
# 50/50 - 0s - loss: 2.3506 - acc: 0.0911 - 406ms/epoch - 8ms/step
# Epoch 11/400
# 50/50 - 0s - loss: 2.3374 - acc: 0.0991 - 378ms/epoch - 8ms/step
# Epoch 12/400
# 50/50 - 0s - loss: 2.3200 - acc: 0.1001 - 395ms/epoch - 8ms/step
# Epoch 13/400
# 50/50 - 0s - loss: 2.3185 - acc: 0.1011 - 413ms/epoch - 8ms/step
# Epoch 14/400
# 50/50 - 0s - loss: 2.3147 - acc: 0.1071 - 380ms/epoch - 8ms/step
# Epoch 15/400
# 50/50 - 0s - loss: 2.3100 - acc: 0.1021 - 371ms/epoch - 7ms/step
# Epoch 16/400
# 50/50 - 0s - loss: 2.3118 - acc: 0.1081 - 422ms/epoch - 8ms/step
# Epoch 17/400
# 50/50 - 0s - loss: 2.3141 - acc: 0.1031 - 394ms/epoch - 8ms/step
# Epoch 18/400
# 50/50 - 0s - loss: 2.3187 - acc: 0.0891 - 406ms/epoch - 8ms/step
# Epoch 19/400
# 50/50 - 0s - loss: 2.3126 - acc: 0.0821 - 395ms/epoch - 8ms/step
# Epoch 20/400
# 50/50 - 0s - loss: 2.2939 - acc: 0.1271 - 390ms/epoch - 8ms/step
# Epoch 21/400
# 50/50 - 0s - loss: 2.3097 - acc: 0.0911 - 358ms/epoch - 7ms/step
# Epoch 22/400
# 50/50 - 0s - loss: 2.3068 - acc: 0.1101 - 428ms/epoch - 9ms/step
# Epoch 23/400
# 50/50 - 0s - loss: 2.2975 - acc: 0.1111 - 442ms/epoch - 9ms/step
# Epoch 24/400
# 50/50 - 0s - loss: 2.2583 - acc: 0.1391 - 397ms/epoch - 8ms/step
# Epoch 25/400
# 50/50 - 0s - loss: 2.2362 - acc: 0.1431 - 364ms/epoch - 7ms/step
# Epoch 26/400
# 50/50 - 0s - loss: 2.2327 - acc: 0.1542 - 376ms/epoch - 8ms/step
# Epoch 27/400
# 50/50 - 0s - loss: 2.2349 - acc: 0.1471 - 387ms/epoch - 8ms/step
# Epoch 28/400
# 50/50 - 0s - loss: 2.2009 - acc: 0.1882 - 466ms/epoch - 9ms/step
# Epoch 29/400
# 50/50 - 0s - loss: 2.1948 - acc: 0.1872 - 383ms/epoch - 8ms/step
# Epoch 30/400
# 50/50 - 0s - loss: 2.1889 - acc: 0.1842 - 370ms/epoch - 7ms/step
# Epoch 31/400
# 50/50 - 0s - loss: 2.2091 - acc: 0.1632 - 395ms/epoch - 8ms/step
# Epoch 32/400
# 50/50 - 0s - loss: 2.1872 - acc: 0.1952 - 394ms/epoch - 8ms/step
# Epoch 33/400
# 50/50 - 0s - loss: 2.2058 - acc: 0.1702 - 393ms/epoch - 8ms/step
# Epoch 34/400
# 50/50 - 0s - loss: 2.1986 - acc: 0.1632 - 380ms/epoch - 8ms/step
# Epoch 35/400
# 50/50 - 0s - loss: 2.2122 - acc: 0.1692 - 430ms/epoch - 9ms/step
# Epoch 36/400
# 50/50 - 0s - loss: 2.1780 - acc: 0.1712 - 395ms/epoch - 8ms/step
# Epoch 37/400
# 50/50 - 0s - loss: 2.1725 - acc: 0.1932 - 387ms/epoch - 8ms/step
# Epoch 38/400
# 50/50 - 0s - loss: 2.1734 - acc: 0.1862 - 380ms/epoch - 8ms/step
# Epoch 39/400
# 50/50 - 0s - loss: 2.1676 - acc: 0.2092 - 401ms/epoch - 8ms/step
# Epoch 40/400
# 50/50 - 0s - loss: 2.1624 - acc: 0.2012 - 417ms/epoch - 8ms/step
# Epoch 41/400
# 50/50 - 0s - loss: 2.1760 - acc: 0.1782 - 390ms/epoch - 8ms/step
# Epoch 42/400
# 50/50 - 0s - loss: 2.1579 - acc: 0.1992 - 359ms/epoch - 7ms/step
# Epoch 43/400
# 50/50 - 0s - loss: 2.1715 - acc: 0.1972 - 383ms/epoch - 8ms/step
# Epoch 44/400
# 50/50 - 0s - loss: 2.2103 - acc: 0.1722 - 420ms/epoch - 8ms/step
# Epoch 45/400
# 50/50 - 0s - loss: 2.1751 - acc: 0.1882 - 379ms/epoch - 8ms/step
# Epoch 46/400
# 50/50 - 0s - loss: 2.1554 - acc: 0.1942 - 364ms/epoch - 7ms/step
# Epoch 47/400
# 50/50 - 0s - loss: 2.1573 - acc: 0.2062 - 376ms/epoch - 8ms/step
# Epoch 48/400
# 50/50 - 0s - loss: 2.1623 - acc: 0.2122 - 444ms/epoch - 9ms/step
# Epoch 49/400
# 50/50 - 0s - loss: 2.1830 - acc: 0.1892 - 391ms/epoch - 8ms/step
# Epoch 50/400
# 50/50 - 0s - loss: 2.1815 - acc: 0.1662 - 381ms/epoch - 8ms/step
# Epoch 51/400
# 50/50 - 0s - loss: 2.1666 - acc: 0.1942 - 380ms/epoch - 8ms/step
# Epoch 52/400
# 50/50 - 0s - loss: 2.1562 - acc: 0.1792 - 404ms/epoch - 8ms/step
# Epoch 53/400
# 50/50 - 0s - loss: 2.1554 - acc: 0.1932 - 396ms/epoch - 8ms/step
# Epoch 54/400
# 50/50 - 0s - loss: 2.1607 - acc: 0.2022 - 408ms/epoch - 8ms/step
# Epoch 55/400
# 50/50 - 0s - loss: 2.1561 - acc: 0.1922 - 378ms/epoch - 8ms/step
# Epoch 56/400
# 50/50 - 0s - loss: 2.1519 - acc: 0.2062 - 411ms/epoch - 8ms/step
# Epoch 57/400
# 50/50 - 0s - loss: 2.1782 - acc: 0.1792 - 384ms/epoch - 8ms/step
# Epoch 58/400
# 50/50 - 0s - loss: 2.1530 - acc: 0.2002 - 397ms/epoch - 8ms/step
# Epoch 59/400
# 50/50 - 0s - loss: 2.1555 - acc: 0.1892 - 392ms/epoch - 8ms/step
# Epoch 60/400
# 50/50 - 0s - loss: 2.1548 - acc: 0.2062 - 399ms/epoch - 8ms/step
# Epoch 61/400
# 50/50 - 0s - loss: 2.1565 - acc: 0.2042 - 426ms/epoch - 9ms/step
# Epoch 62/400
# 50/50 - 0s - loss: 2.1617 - acc: 0.1992 - 392ms/epoch - 8ms/step
# Epoch 63/400
# 50/50 - 0s - loss: 2.1510 - acc: 0.1912 - 364ms/epoch - 7ms/step
# Epoch 64/400
# 50/50 - 0s - loss: 2.1447 - acc: 0.2082 - 387ms/epoch - 8ms/step
# Epoch 65/400
# 50/50 - 0s - loss: 2.1504 - acc: 0.2082 - 361ms/epoch - 7ms/step
# Epoch 66/400
# 50/50 - 0s - loss: 2.1594 - acc: 0.1822 - 400ms/epoch - 8ms/step
# Epoch 67/400
# 50/50 - 0s - loss: 2.1694 - acc: 0.1962 - 349ms/epoch - 7ms/step
# Epoch 68/400
# 50/50 - 0s - loss: 2.1507 - acc: 0.1912 - 383ms/epoch - 8ms/step
# Epoch 69/400
# 50/50 - 0s - loss: 2.1479 - acc: 0.2042 - 390ms/epoch - 8ms/step
# Epoch 70/400
# 50/50 - 0s - loss: 2.1443 - acc: 0.1922 - 380ms/epoch - 8ms/step
# Epoch 71/400
# 50/50 - 0s - loss: 2.1417 - acc: 0.1912 - 381ms/epoch - 8ms/step
# Epoch 72/400
# 50/50 - 0s - loss: 2.1549 - acc: 0.2012 - 381ms/epoch - 8ms/step
# Epoch 73/400
# 50/50 - 0s - loss: 2.1452 - acc: 0.2032 - 391ms/epoch - 8ms/step
# Epoch 74/400
# 50/50 - 0s - loss: 2.1364 - acc: 0.2172 - 373ms/epoch - 7ms/step
# Epoch 75/400
# 50/50 - 0s - loss: 2.1529 - acc: 0.1922 - 351ms/epoch - 7ms/step
# Epoch 76/400
# 50/50 - 0s - loss: 2.1339 - acc: 0.2202 - 391ms/epoch - 8ms/step
# Epoch 77/400
# 50/50 - 0s - loss: 2.1519 - acc: 0.2122 - 374ms/epoch - 7ms/step
# Epoch 78/400
# 50/50 - 0s - loss: 2.1297 - acc: 0.2252 - 365ms/epoch - 7ms/step
# Epoch 79/400
# 50/50 - 0s - loss: 2.1375 - acc: 0.2052 - 357ms/epoch - 7ms/step
# Epoch 80/400
# 50/50 - 0s - loss: 2.1258 - acc: 0.2152 - 357ms/epoch - 7ms/step
# Epoch 81/400
# 50/50 - 0s - loss: 2.1180 - acc: 0.2212 - 350ms/epoch - 7ms/step
# Epoch 82/400
# 50/50 - 0s - loss: 2.1222 - acc: 0.2082 - 396ms/epoch - 8ms/step
# Epoch 83/400
# 50/50 - 0s - loss: 2.1077 - acc: 0.2242 - 384ms/epoch - 8ms/step
# Epoch 84/400
# 50/50 - 0s - loss: 2.0876 - acc: 0.2402 - 359ms/epoch - 7ms/step
# Epoch 85/400
# 50/50 - 0s - loss: 2.0845 - acc: 0.2472 - 435ms/epoch - 9ms/step
# Epoch 86/400
# 50/50 - 0s - loss: 2.0584 - acc: 0.2563 - 379ms/epoch - 8ms/step
# Epoch 87/400
# 50/50 - 0s - loss: 2.0716 - acc: 0.2362 - 380ms/epoch - 8ms/step
# Epoch 88/400
# 50/50 - 0s - loss: 2.0439 - acc: 0.2482 - 363ms/epoch - 7ms/step
# Epoch 89/400
# 50/50 - 0s - loss: 2.0102 - acc: 0.2783 - 369ms/epoch - 7ms/step
# Epoch 90/400
# 50/50 - 0s - loss: 1.9758 - acc: 0.2803 - 387ms/epoch - 8ms/step
# Epoch 91/400
# 50/50 - 0s - loss: 1.9802 - acc: 0.2653 - 414ms/epoch - 8ms/step
# Epoch 92/400
# 50/50 - 0s - loss: 1.9647 - acc: 0.2733 - 399ms/epoch - 8ms/step
# Epoch 93/400
# 50/50 - 0s - loss: 1.9402 - acc: 0.2683 - 359ms/epoch - 7ms/step
# Epoch 94/400
# 50/50 - 0s - loss: 1.8859 - acc: 0.2923 - 390ms/epoch - 8ms/step
# Epoch 95/400
# 50/50 - 0s - loss: 1.9030 - acc: 0.2973 - 346ms/epoch - 7ms/step
# Epoch 96/400
# 50/50 - 0s - loss: 1.8462 - acc: 0.3053 - 428ms/epoch - 9ms/step
# Epoch 97/400
# 50/50 - 0s - loss: 1.8292 - acc: 0.3203 - 367ms/epoch - 7ms/step
# Epoch 98/400
# 50/50 - 0s - loss: 1.8396 - acc: 0.3053 - 404ms/epoch - 8ms/step
# Epoch 99/400
# 50/50 - 0s - loss: 1.8016 - acc: 0.3353 - 356ms/epoch - 7ms/step
# Epoch 100/400
# 50/50 - 0s - loss: 1.7909 - acc: 0.3283 - 351ms/epoch - 7ms/step
# Epoch 101/400
# 50/50 - 0s - loss: 1.7836 - acc: 0.3333 - 375ms/epoch - 8ms/step
# Epoch 102/400
# 50/50 - 0s - loss: 1.7516 - acc: 0.3493 - 372ms/epoch - 7ms/step
# Epoch 103/400
# 50/50 - 0s - loss: 1.7853 - acc: 0.3333 - 381ms/epoch - 8ms/step
# Epoch 104/400
# 50/50 - 0s - loss: 1.7544 - acc: 0.3724 - 406ms/epoch - 8ms/step
# Epoch 105/400
# 50/50 - 0s - loss: 1.7102 - acc: 0.3594 - 415ms/epoch - 8ms/step
# Epoch 106/400
# 50/50 - 0s - loss: 1.6989 - acc: 0.3594 - 395ms/epoch - 8ms/step
# Epoch 107/400
# 50/50 - 0s - loss: 1.6865 - acc: 0.3634 - 387ms/epoch - 8ms/step
# Epoch 108/400
# 50/50 - 0s - loss: 1.7251 - acc: 0.3373 - 380ms/epoch - 8ms/step
# Epoch 109/400
# 50/50 - 0s - loss: 1.6786 - acc: 0.3584 - 404ms/epoch - 8ms/step
# Epoch 110/400
# 50/50 - 0s - loss: 1.7249 - acc: 0.3463 - 371ms/epoch - 7ms/step
# Epoch 111/400
# 50/50 - 0s - loss: 1.6523 - acc: 0.3604 - 364ms/epoch - 7ms/step
# Epoch 112/400
# 50/50 - 0s - loss: 1.6729 - acc: 0.3664 - 400ms/epoch - 8ms/step
# Epoch 113/400
# 50/50 - 0s - loss: 1.6341 - acc: 0.3894 - 370ms/epoch - 7ms/step
# Epoch 114/400
# 50/50 - 0s - loss: 1.6787 - acc: 0.3413 - 347ms/epoch - 7ms/step
# Epoch 115/400
# 50/50 - 0s - loss: 1.6180 - acc: 0.3694 - 383ms/epoch - 8ms/step
# Epoch 116/400
# 50/50 - 0s - loss: 1.5825 - acc: 0.4024 - 359ms/epoch - 7ms/step
# Epoch 117/400
# 50/50 - 0s - loss: 1.5431 - acc: 0.4264 - 389ms/epoch - 8ms/step
# Epoch 118/400
# 50/50 - 0s - loss: 1.5651 - acc: 0.4014 - 416ms/epoch - 8ms/step
# Epoch 119/400
# 50/50 - 0s - loss: 1.5844 - acc: 0.4044 - 360ms/epoch - 7ms/step
# Epoch 120/400
# 50/50 - 0s - loss: 1.6376 - acc: 0.3894 - 409ms/epoch - 8ms/step
# Epoch 121/400
# 50/50 - 0s - loss: 1.5390 - acc: 0.4044 - 386ms/epoch - 8ms/step
# Epoch 122/400
# 50/50 - 0s - loss: 1.5806 - acc: 0.3884 - 400ms/epoch - 8ms/step
# Epoch 123/400
# 50/50 - 0s - loss: 1.5057 - acc: 0.4374 - 365ms/epoch - 7ms/step
# Epoch 124/400
# 50/50 - 0s - loss: 1.4718 - acc: 0.4324 - 384ms/epoch - 8ms/step
# Epoch 125/400
# 50/50 - 0s - loss: 1.5065 - acc: 0.4204 - 387ms/epoch - 8ms/step
# Epoch 126/400
# 50/50 - 0s - loss: 1.4444 - acc: 0.4505 - 364ms/epoch - 7ms/step
# Epoch 127/400
# 50/50 - 0s - loss: 1.4102 - acc: 0.4665 - 365ms/epoch - 7ms/step
# Epoch 128/400
# 50/50 - 0s - loss: 1.4482 - acc: 0.4434 - 367ms/epoch - 7ms/step
# Epoch 129/400
# 50/50 - 0s - loss: 1.4035 - acc: 0.4655 - 413ms/epoch - 8ms/step
# Epoch 130/400
# 50/50 - 0s - loss: 1.4012 - acc: 0.4535 - 384ms/epoch - 8ms/step
# Epoch 131/400
# 50/50 - 0s - loss: 1.4000 - acc: 0.4625 - 346ms/epoch - 7ms/step
# Epoch 132/400
# 50/50 - 0s - loss: 1.3967 - acc: 0.4565 - 399ms/epoch - 8ms/step
# Epoch 133/400
# 50/50 - 0s - loss: 1.3379 - acc: 0.4945 - 368ms/epoch - 7ms/step
# Epoch 134/400
# 50/50 - 0s - loss: 1.4132 - acc: 0.4745 - 406ms/epoch - 8ms/step
# Epoch 135/400
# 50/50 - 0s - loss: 1.3209 - acc: 0.4885 - 391ms/epoch - 8ms/step
# Epoch 136/400
# 50/50 - 0s - loss: 1.3989 - acc: 0.4444 - 386ms/epoch - 8ms/step
# Epoch 137/400
# 50/50 - 0s - loss: 1.3009 - acc: 0.5145 - 412ms/epoch - 8ms/step
# Epoch 138/400
# 50/50 - 0s - loss: 1.2285 - acc: 0.5285 - 423ms/epoch - 8ms/step
# Epoch 139/400
# 50/50 - 0s - loss: 1.2110 - acc: 0.5415 - 361ms/epoch - 7ms/step
# Epoch 140/400
# 50/50 - 0s - loss: 1.2436 - acc: 0.5105 - 356ms/epoch - 7ms/step
# Epoch 141/400
# 50/50 - 0s - loss: 1.2571 - acc: 0.5235 - 365ms/epoch - 7ms/step
# Epoch 142/400
# 50/50 - 0s - loss: 1.1841 - acc: 0.5435 - 361ms/epoch - 7ms/step
# Epoch 143/400
# 50/50 - 0s - loss: 1.1733 - acc: 0.5445 - 396ms/epoch - 8ms/step
# Epoch 144/400
# 50/50 - 0s - loss: 1.1264 - acc: 0.5756 - 407ms/epoch - 8ms/step
# Epoch 145/400
# 50/50 - 0s - loss: 1.1547 - acc: 0.5606 - 431ms/epoch - 9ms/step
# Epoch 146/400
# 50/50 - 0s - loss: 1.0793 - acc: 0.5966 - 370ms/epoch - 7ms/step
# Epoch 147/400
# 50/50 - 0s - loss: 1.0973 - acc: 0.5786 - 369ms/epoch - 7ms/step
# Epoch 148/400
# 50/50 - 0s - loss: 1.1785 - acc: 0.5586 - 375ms/epoch - 7ms/step
# Epoch 149/400
# 50/50 - 0s - loss: 1.0919 - acc: 0.5716 - 399ms/epoch - 8ms/step
# Epoch 150/400
# 50/50 - 0s - loss: 1.0675 - acc: 0.5936 - 382ms/epoch - 8ms/step
# Epoch 151/400
# 50/50 - 0s - loss: 1.0327 - acc: 0.5866 - 419ms/epoch - 8ms/step
# Epoch 152/400
# 50/50 - 0s - loss: 1.0323 - acc: 0.6016 - 356ms/epoch - 7ms/step
# Epoch 153/400
# 50/50 - 0s - loss: 1.0409 - acc: 0.5856 - 425ms/epoch - 8ms/step
# Epoch 154/400
# 50/50 - 0s - loss: 1.0309 - acc: 0.6016 - 392ms/epoch - 8ms/step
# Epoch 155/400
# 50/50 - 0s - loss: 0.9679 - acc: 0.6156 - 368ms/epoch - 7ms/step
# Epoch 156/400
# 50/50 - 0s - loss: 0.9791 - acc: 0.5996 - 376ms/epoch - 8ms/step
# Epoch 157/400
# 50/50 - 0s - loss: 0.9852 - acc: 0.6186 - 380ms/epoch - 8ms/step
# Epoch 158/400
# 50/50 - 0s - loss: 0.9435 - acc: 0.6396 - 380ms/epoch - 8ms/step
# Epoch 159/400
# 50/50 - 0s - loss: 0.9046 - acc: 0.6507 - 388ms/epoch - 8ms/step
# Epoch 160/400
# 50/50 - 0s - loss: 1.0626 - acc: 0.5756 - 453ms/epoch - 9ms/step
# Epoch 161/400
# 50/50 - 0s - loss: 0.9359 - acc: 0.6346 - 379ms/epoch - 8ms/step
# Epoch 162/400
# 50/50 - 0s - loss: 0.9401 - acc: 0.6296 - 347ms/epoch - 7ms/step
# Epoch 163/400
# 50/50 - 0s - loss: 0.8671 - acc: 0.6817 - 364ms/epoch - 7ms/step
# Epoch 164/400
# 50/50 - 0s - loss: 0.8743 - acc: 0.6597 - 389ms/epoch - 8ms/step
# Epoch 165/400
# 50/50 - 0s - loss: 0.8543 - acc: 0.6667 - 391ms/epoch - 8ms/step
# Epoch 166/400
# 50/50 - 0s - loss: 0.8367 - acc: 0.6817 - 374ms/epoch - 7ms/step
# Epoch 167/400
# 50/50 - 0s - loss: 0.8046 - acc: 0.6977 - 393ms/epoch - 8ms/step
# Epoch 168/400
# 50/50 - 0s - loss: 0.8138 - acc: 0.6947 - 394ms/epoch - 8ms/step
# Epoch 169/400
# 50/50 - 0s - loss: 0.7806 - acc: 0.6967 - 391ms/epoch - 8ms/step
# Epoch 170/400
# 50/50 - 0s - loss: 0.7599 - acc: 0.6957 - 379ms/epoch - 8ms/step
# Epoch 171/400
# 50/50 - 0s - loss: 0.7388 - acc: 0.7197 - 380ms/epoch - 8ms/step
# Epoch 172/400
# 50/50 - 0s - loss: 0.7521 - acc: 0.7077 - 375ms/epoch - 7ms/step
# Epoch 173/400
# 50/50 - 0s - loss: 0.7466 - acc: 0.7097 - 367ms/epoch - 7ms/step
# Epoch 174/400
# 50/50 - 0s - loss: 0.7533 - acc: 0.7147 - 358ms/epoch - 7ms/step
# Epoch 175/400
# 50/50 - 0s - loss: 0.7142 - acc: 0.7257 - 372ms/epoch - 7ms/step
# Epoch 176/400
# 50/50 - 0s - loss: 0.7330 - acc: 0.7207 - 395ms/epoch - 8ms/step
# Epoch 177/400
# 50/50 - 0s - loss: 0.7850 - acc: 0.6937 - 357ms/epoch - 7ms/step
# Epoch 178/400
# 50/50 - 0s - loss: 0.6360 - acc: 0.7518 - 369ms/epoch - 7ms/step
# Epoch 179/400
# 50/50 - 0s - loss: 0.6450 - acc: 0.7608 - 359ms/epoch - 7ms/step
# Epoch 180/400
# 50/50 - 0s - loss: 0.5782 - acc: 0.7838 - 381ms/epoch - 8ms/step
# Epoch 181/400
# 50/50 - 0s - loss: 0.6574 - acc: 0.7538 - 377ms/epoch - 8ms/step
# Epoch 182/400
# 50/50 - 0s - loss: 0.7554 - acc: 0.7187 - 380ms/epoch - 8ms/step
# Epoch 183/400
# 50/50 - 0s - loss: 0.7155 - acc: 0.7227 - 444ms/epoch - 9ms/step
# Epoch 184/400
# 50/50 - 0s - loss: 0.6153 - acc: 0.7708 - 375ms/epoch - 7ms/step
# Epoch 185/400
# 50/50 - 0s - loss: 0.5991 - acc: 0.7748 - 374ms/epoch - 7ms/step
# Epoch 186/400
# 50/50 - 0s - loss: 0.5715 - acc: 0.7918 - 371ms/epoch - 7ms/step
# Epoch 187/400
# 50/50 - 0s - loss: 0.5823 - acc: 0.7868 - 350ms/epoch - 7ms/step
# Epoch 188/400
# 50/50 - 0s - loss: 0.5768 - acc: 0.8008 - 347ms/epoch - 7ms/step
# Epoch 189/400
# 50/50 - 0s - loss: 0.5656 - acc: 0.8128 - 380ms/epoch - 8ms/step
# Epoch 190/400
# 50/50 - 0s - loss: 0.6036 - acc: 0.7698 - 371ms/epoch - 7ms/step
# Epoch 191/400
# 50/50 - 0s - loss: 0.5452 - acc: 0.8098 - 362ms/epoch - 7ms/step
# Epoch 192/400
# 50/50 - 0s - loss: 0.5578 - acc: 0.8008 - 376ms/epoch - 8ms/step
# Epoch 193/400
# 50/50 - 0s - loss: 0.5231 - acc: 0.8238 - 404ms/epoch - 8ms/step
# Epoch 194/400
# 50/50 - 0s - loss: 0.5278 - acc: 0.8048 - 377ms/epoch - 8ms/step
# Epoch 195/400
# 50/50 - 0s - loss: 0.4675 - acc: 0.8549 - 371ms/epoch - 7ms/step
# Epoch 196/400
# 50/50 - 0s - loss: 0.5337 - acc: 0.8108 - 371ms/epoch - 7ms/step
# Epoch 197/400
# 50/50 - 0s - loss: 0.6308 - acc: 0.7808 - 386ms/epoch - 8ms/step
# Epoch 198/400
# 50/50 - 0s - loss: 0.5433 - acc: 0.8008 - 415ms/epoch - 8ms/step
# Epoch 199/400
# 50/50 - 0s - loss: 0.5030 - acc: 0.8268 - 426ms/epoch - 9ms/step
# Epoch 200/400
# 50/50 - 0s - loss: 0.5746 - acc: 0.8008 - 364ms/epoch - 7ms/step
# Epoch 201/400
# 50/50 - 0s - loss: 0.4353 - acc: 0.8659 - 388ms/epoch - 8ms/step
# Epoch 202/400
# 50/50 - 0s - loss: 0.4697 - acc: 0.8358 - 365ms/epoch - 7ms/step
# Epoch 203/400
# 50/50 - 0s - loss: 0.4390 - acc: 0.8559 - 393ms/epoch - 8ms/step
# Epoch 204/400
# 50/50 - 0s - loss: 0.4576 - acc: 0.8559 - 366ms/epoch - 7ms/step
# Epoch 205/400
# 50/50 - 0s - loss: 0.4355 - acc: 0.8498 - 347ms/epoch - 7ms/step
# Epoch 206/400
# 50/50 - 0s - loss: 0.4091 - acc: 0.8569 - 437ms/epoch - 9ms/step
# Epoch 207/400
# 50/50 - 0s - loss: 0.5858 - acc: 0.7968 - 394ms/epoch - 8ms/step
# Epoch 208/400
# 50/50 - 0s - loss: 0.4264 - acc: 0.8599 - 403ms/epoch - 8ms/step
# Epoch 209/400
# 50/50 - 0s - loss: 0.3250 - acc: 0.9029 - 396ms/epoch - 8ms/step
# Epoch 210/400
# 50/50 - 0s - loss: 0.3928 - acc: 0.8669 - 403ms/epoch - 8ms/step
# Epoch 211/400
# 50/50 - 0s - loss: 0.3873 - acc: 0.8759 - 388ms/epoch - 8ms/step
# Epoch 212/400
# 50/50 - 0s - loss: 0.3684 - acc: 0.8819 - 410ms/epoch - 8ms/step
# Epoch 213/400
# 50/50 - 0s - loss: 0.3638 - acc: 0.8779 - 408ms/epoch - 8ms/step
# Epoch 214/400
# 50/50 - 0s - loss: 0.4116 - acc: 0.8529 - 360ms/epoch - 7ms/step
# Epoch 215/400
# 50/50 - 0s - loss: 0.5326 - acc: 0.8048 - 366ms/epoch - 7ms/step
# Epoch 216/400
# 50/50 - 0s - loss: 0.4662 - acc: 0.8378 - 383ms/epoch - 8ms/step
# Epoch 217/400
# 50/50 - 0s - loss: 0.3578 - acc: 0.8819 - 367ms/epoch - 7ms/step
# Epoch 218/400
# 50/50 - 0s - loss: 0.3179 - acc: 0.9119 - 365ms/epoch - 7ms/step
# Epoch 219/400
# 50/50 - 0s - loss: 0.2939 - acc: 0.9129 - 402ms/epoch - 8ms/step
# Epoch 220/400
# 50/50 - 0s - loss: 0.2811 - acc: 0.9179 - 388ms/epoch - 8ms/step
# Epoch 221/400
# 50/50 - 0s - loss: 0.3778 - acc: 0.8609 - 385ms/epoch - 8ms/step
# Epoch 222/400
# 50/50 - 0s - loss: 0.4396 - acc: 0.8539 - 421ms/epoch - 8ms/step
# Epoch 223/400
# 50/50 - 0s - loss: 0.4568 - acc: 0.8579 - 399ms/epoch - 8ms/step
# Epoch 224/400
# 50/50 - 0s - loss: 0.3418 - acc: 0.8899 - 384ms/epoch - 8ms/step
# Epoch 225/400
# 50/50 - 0s - loss: 0.3429 - acc: 0.8819 - 390ms/epoch - 8ms/step
# Epoch 226/400
# 50/50 - 0s - loss: 0.2612 - acc: 0.9229 - 412ms/epoch - 8ms/step
# Epoch 227/400
# 50/50 - 0s - loss: 0.2272 - acc: 0.9399 - 411ms/epoch - 8ms/step
# Epoch 228/400
# 50/50 - 0s - loss: 0.2741 - acc: 0.9219 - 411ms/epoch - 8ms/step
# Epoch 229/400
# 50/50 - 0s - loss: 0.2617 - acc: 0.9229 - 377ms/epoch - 8ms/step
# Epoch 230/400
# 50/50 - 0s - loss: 0.2691 - acc: 0.9259 - 400ms/epoch - 8ms/step
# Epoch 231/400
# 50/50 - 0s - loss: 0.3418 - acc: 0.8839 - 375ms/epoch - 8ms/step
# Epoch 232/400
# 50/50 - 0s - loss: 0.3194 - acc: 0.8959 - 379ms/epoch - 8ms/step
# Epoch 233/400
# 50/50 - 0s - loss: 0.2538 - acc: 0.9259 - 441ms/epoch - 9ms/step
# Epoch 234/400
# 50/50 - 0s - loss: 0.2551 - acc: 0.9239 - 387ms/epoch - 8ms/step
# Epoch 235/400
# 50/50 - 0s - loss: 0.3633 - acc: 0.8799 - 351ms/epoch - 7ms/step
# Epoch 236/400
# 50/50 - 0s - loss: 0.4565 - acc: 0.8458 - 366ms/epoch - 7ms/step
# Epoch 237/400
# 50/50 - 0s - loss: 0.3767 - acc: 0.8749 - 384ms/epoch - 8ms/step
# Epoch 238/400
# 50/50 - 0s - loss: 0.3335 - acc: 0.8919 - 390ms/epoch - 8ms/step
# Epoch 239/400
# 50/50 - 0s - loss: 0.2505 - acc: 0.9179 - 403ms/epoch - 8ms/step
# Epoch 240/400
# 50/50 - 0s - loss: 0.2607 - acc: 0.9219 - 387ms/epoch - 8ms/step
# Epoch 241/400
# 50/50 - 0s - loss: 0.2383 - acc: 0.9389 - 378ms/epoch - 8ms/step
# Epoch 242/400
# 50/50 - 0s - loss: 0.2164 - acc: 0.9399 - 377ms/epoch - 8ms/step
# Epoch 243/400
# 50/50 - 0s - loss: 0.2615 - acc: 0.9199 - 432ms/epoch - 9ms/step
# Epoch 244/400
# 50/50 - 0s - loss: 0.4294 - acc: 0.8368 - 397ms/epoch - 8ms/step
# Epoch 245/400
# 50/50 - 0s - loss: 0.4942 - acc: 0.8368 - 424ms/epoch - 8ms/step
# Epoch 246/400
# 50/50 - 0s - loss: 0.3019 - acc: 0.8999 - 388ms/epoch - 8ms/step
# Epoch 247/400
# 50/50 - 0s - loss: 0.2373 - acc: 0.9279 - 400ms/epoch - 8ms/step
# Epoch 248/400
# 50/50 - 0s - loss: 0.1968 - acc: 0.9389 - 432ms/epoch - 9ms/step
# Epoch 249/400
# 50/50 - 0s - loss: 0.1690 - acc: 0.9580 - 368ms/epoch - 7ms/step
# Epoch 250/400
# 50/50 - 0s - loss: 0.2211 - acc: 0.9389 - 376ms/epoch - 8ms/step
# Epoch 251/400
# 50/50 - 0s - loss: 0.2510 - acc: 0.9229 - 450ms/epoch - 9ms/step
# Epoch 252/400
# 50/50 - 0s - loss: 0.2338 - acc: 0.9279 - 389ms/epoch - 8ms/step
# Epoch 253/400
# 50/50 - 0s - loss: 0.2840 - acc: 0.9139 - 395ms/epoch - 8ms/step
# Epoch 254/400
# 50/50 - 0s - loss: 0.4865 - acc: 0.8288 - 407ms/epoch - 8ms/step
# Epoch 255/400
# 50/50 - 0s - loss: 0.2779 - acc: 0.9189 - 380ms/epoch - 8ms/step
# Epoch 256/400
# 50/50 - 0s - loss: 0.2683 - acc: 0.9149 - 392ms/epoch - 8ms/step
# Epoch 257/400
# 50/50 - 0s - loss: 0.2263 - acc: 0.9299 - 402ms/epoch - 8ms/step
# Epoch 258/400
# 50/50 - 0s - loss: 0.2126 - acc: 0.9359 - 434ms/epoch - 9ms/step
# Epoch 259/400
# 50/50 - 0s - loss: 0.1776 - acc: 0.9449 - 407ms/epoch - 8ms/step
# Epoch 260/400
# 50/50 - 0s - loss: 0.2652 - acc: 0.9139 - 385ms/epoch - 8ms/step
# Epoch 261/400
# 50/50 - 0s - loss: 0.2725 - acc: 0.9099 - 394ms/epoch - 8ms/step
# Epoch 262/400
# 50/50 - 0s - loss: 0.2728 - acc: 0.9099 - 377ms/epoch - 8ms/step
# Epoch 263/400
# 50/50 - 0s - loss: 0.3063 - acc: 0.8919 - 373ms/epoch - 7ms/step
# Epoch 264/400
# 50/50 - 0s - loss: 0.2571 - acc: 0.9199 - 384ms/epoch - 8ms/step
# Epoch 265/400
# 50/50 - 0s - loss: 0.1861 - acc: 0.9429 - 380ms/epoch - 8ms/step
# Epoch 266/400
# 50/50 - 0s - loss: 0.2156 - acc: 0.9359 - 378ms/epoch - 8ms/step
# Epoch 267/400
# 50/50 - 0s - loss: 0.3258 - acc: 0.8919 - 391ms/epoch - 8ms/step
# Epoch 268/400
# 50/50 - 0s - loss: 0.2573 - acc: 0.9199 - 374ms/epoch - 7ms/step
# Epoch 269/400
# 50/50 - 0s - loss: 0.2381 - acc: 0.9259 - 415ms/epoch - 8ms/step
# Epoch 270/400
# 50/50 - 0s - loss: 0.2410 - acc: 0.9159 - 369ms/epoch - 7ms/step
# Epoch 271/400
# 50/50 - 0s - loss: 0.1784 - acc: 0.9489 - 402ms/epoch - 8ms/step
# Epoch 272/400
# 50/50 - 0s - loss: 0.1366 - acc: 0.9680 - 411ms/epoch - 8ms/step
# Epoch 273/400
# 50/50 - 0s - loss: 0.1270 - acc: 0.9710 - 390ms/epoch - 8ms/step
# Epoch 274/400
# 50/50 - 0s - loss: 0.1714 - acc: 0.9499 - 370ms/epoch - 7ms/step
# Epoch 275/400
# 50/50 - 0s - loss: 0.2941 - acc: 0.8999 - 366ms/epoch - 7ms/step
# Epoch 276/400
# 50/50 - 0s - loss: 0.2060 - acc: 0.9419 - 394ms/epoch - 8ms/step
# Epoch 277/400
# 50/50 - 0s - loss: 0.1536 - acc: 0.9550 - 423ms/epoch - 8ms/step
# Epoch 278/400
# 50/50 - 0s - loss: 0.2210 - acc: 0.9339 - 383ms/epoch - 8ms/step
# Epoch 279/400
# 50/50 - 0s - loss: 0.1609 - acc: 0.9530 - 396ms/epoch - 8ms/step
# Epoch 280/400
# 50/50 - 0s - loss: 0.1149 - acc: 0.9720 - 431ms/epoch - 9ms/step
# Epoch 281/400
# 50/50 - 0s - loss: 0.0841 - acc: 0.9810 - 402ms/epoch - 8ms/step
# Epoch 282/400
# 50/50 - 0s - loss: 0.1111 - acc: 0.9690 - 384ms/epoch - 8ms/step
# Epoch 283/400
# 50/50 - 0s - loss: 0.1650 - acc: 0.9520 - 455ms/epoch - 9ms/step
# Epoch 284/400
# 50/50 - 0s - loss: 0.2617 - acc: 0.9159 - 451ms/epoch - 9ms/step
# Epoch 285/400
# 50/50 - 0s - loss: 0.2272 - acc: 0.9359 - 411ms/epoch - 8ms/step
# Epoch 286/400
# 50/50 - 0s - loss: 0.2801 - acc: 0.8999 - 371ms/epoch - 7ms/step
# Epoch 287/400
# 50/50 - 0s - loss: 0.2813 - acc: 0.9019 - 422ms/epoch - 8ms/step
# Epoch 288/400
# 50/50 - 0s - loss: 0.2027 - acc: 0.9379 - 391ms/epoch - 8ms/step
# Epoch 289/400
# 50/50 - 0s - loss: 0.2026 - acc: 0.9389 - 404ms/epoch - 8ms/step
# Epoch 290/400
# 50/50 - 0s - loss: 0.1515 - acc: 0.9510 - 406ms/epoch - 8ms/step
# Epoch 291/400
# 50/50 - 0s - loss: 0.2283 - acc: 0.9229 - 364ms/epoch - 7ms/step
# Epoch 292/400
# 50/50 - 0s - loss: 0.2457 - acc: 0.9279 - 418ms/epoch - 8ms/step
# Epoch 293/400
# 50/50 - 0s - loss: 0.1641 - acc: 0.9489 - 391ms/epoch - 8ms/step
# Epoch 294/400
# 50/50 - 0s - loss: 0.1209 - acc: 0.9650 - 403ms/epoch - 8ms/step
# Epoch 295/400
# 50/50 - 0s - loss: 0.1346 - acc: 0.9580 - 360ms/epoch - 7ms/step
# Epoch 296/400
# 50/50 - 0s - loss: 0.1433 - acc: 0.9510 - 398ms/epoch - 8ms/step
# Epoch 297/400
# 50/50 - 0s - loss: 0.1732 - acc: 0.9520 - 406ms/epoch - 8ms/step
# Epoch 298/400
# 50/50 - 0s - loss: 0.1671 - acc: 0.9459 - 395ms/epoch - 8ms/step
# Epoch 299/400
# 50/50 - 0s - loss: 0.1491 - acc: 0.9620 - 367ms/epoch - 7ms/step
# Epoch 300/400
# 50/50 - 0s - loss: 0.1451 - acc: 0.9550 - 369ms/epoch - 7ms/step
# Epoch 301/400
# 50/50 - 0s - loss: 0.1901 - acc: 0.9329 - 408ms/epoch - 8ms/step
# Epoch 302/400
# 50/50 - 0s - loss: 0.1769 - acc: 0.9439 - 438ms/epoch - 9ms/step
# Epoch 303/400
# 50/50 - 0s - loss: 0.1990 - acc: 0.9389 - 384ms/epoch - 8ms/step
# Epoch 304/400
# 50/50 - 0s - loss: 0.1805 - acc: 0.9479 - 421ms/epoch - 8ms/step
# Epoch 305/400
# 50/50 - 0s - loss: 0.1835 - acc: 0.9449 - 378ms/epoch - 8ms/step
# Epoch 306/400
# 50/50 - 0s - loss: 0.1886 - acc: 0.9429 - 403ms/epoch - 8ms/step
# Epoch 307/400
# 50/50 - 0s - loss: 0.1940 - acc: 0.9369 - 370ms/epoch - 7ms/step
# Epoch 308/400
# 50/50 - 0s - loss: 0.3298 - acc: 0.8859 - 367ms/epoch - 7ms/step
# Epoch 309/400
# 50/50 - 0s - loss: 0.2333 - acc: 0.9229 - 386ms/epoch - 8ms/step
# Epoch 310/400
# 50/50 - 0s - loss: 0.1682 - acc: 0.9449 - 399ms/epoch - 8ms/step
# Epoch 311/400
# 50/50 - 0s - loss: 0.2334 - acc: 0.9259 - 372ms/epoch - 7ms/step
# Epoch 312/400
# 50/50 - 0s - loss: 0.1789 - acc: 0.9449 - 382ms/epoch - 8ms/step
# Epoch 313/400
# 50/50 - 0s - loss: 0.0946 - acc: 0.9780 - 394ms/epoch - 8ms/step
# Epoch 314/400
# 50/50 - 0s - loss: 0.1116 - acc: 0.9610 - 382ms/epoch - 8ms/step
# Epoch 315/400
# 50/50 - 0s - loss: 0.0985 - acc: 0.9700 - 368ms/epoch - 7ms/step
# Epoch 316/400
# 50/50 - 0s - loss: 0.0850 - acc: 0.9810 - 363ms/epoch - 7ms/step
# Epoch 317/400
# 50/50 - 0s - loss: 0.0692 - acc: 0.9810 - 378ms/epoch - 8ms/step
# Epoch 318/400
# 50/50 - 0s - loss: 0.0571 - acc: 0.9850 - 449ms/epoch - 9ms/step
# Epoch 319/400
# 50/50 - 0s - loss: 0.1082 - acc: 0.9680 - 360ms/epoch - 7ms/step
# Epoch 320/400
# 50/50 - 0s - loss: 0.2384 - acc: 0.9299 - 389ms/epoch - 8ms/step
# Epoch 321/400
# 50/50 - 0s - loss: 0.4879 - acc: 0.8478 - 361ms/epoch - 7ms/step
# Epoch 322/400
# 50/50 - 0s - loss: 0.3145 - acc: 0.8939 - 394ms/epoch - 8ms/step
# Epoch 323/400
# 50/50 - 0s - loss: 0.2470 - acc: 0.9069 - 400ms/epoch - 8ms/step
# Epoch 324/400
# 50/50 - 0s - loss: 0.1364 - acc: 0.9590 - 402ms/epoch - 8ms/step
# Epoch 325/400
# 50/50 - 0s - loss: 0.1674 - acc: 0.9469 - 392ms/epoch - 8ms/step
# Epoch 326/400
# 50/50 - 0s - loss: 0.1136 - acc: 0.9680 - 382ms/epoch - 8ms/step
# Epoch 327/400
# 50/50 - 0s - loss: 0.0711 - acc: 0.9850 - 350ms/epoch - 7ms/step
# Epoch 328/400
# 50/50 - 0s - loss: 0.0529 - acc: 0.9900 - 411ms/epoch - 8ms/step
# Epoch 329/400
# 50/50 - 0s - loss: 0.0638 - acc: 0.9870 - 361ms/epoch - 7ms/step
# Epoch 330/400
# 50/50 - 0s - loss: 0.0825 - acc: 0.9780 - 371ms/epoch - 7ms/step
# Epoch 331/400
# 50/50 - 0s - loss: 0.0636 - acc: 0.9840 - 393ms/epoch - 8ms/step
# Epoch 332/400
# 50/50 - 0s - loss: 0.0517 - acc: 0.9890 - 403ms/epoch - 8ms/step
# Epoch 333/400
# 50/50 - 0s - loss: 0.0532 - acc: 0.9860 - 399ms/epoch - 8ms/step
# Epoch 334/400
# 50/50 - 0s - loss: 0.0632 - acc: 0.9900 - 363ms/epoch - 7ms/step
# Epoch 335/400
# 50/50 - 0s - loss: 0.0481 - acc: 0.9910 - 409ms/epoch - 8ms/step
# Epoch 336/400
# 50/50 - 0s - loss: 0.0944 - acc: 0.9730 - 383ms/epoch - 8ms/step
# Epoch 337/400
# 50/50 - 0s - loss: 0.2757 - acc: 0.9149 - 405ms/epoch - 8ms/step
# Epoch 338/400
# 50/50 - 0s - loss: 0.3619 - acc: 0.8979 - 366ms/epoch - 7ms/step
# Epoch 339/400
# 50/50 - 0s - loss: 0.5801 - acc: 0.8058 - 378ms/epoch - 8ms/step
# Epoch 340/400
# 50/50 - 0s - loss: 0.2432 - acc: 0.9269 - 425ms/epoch - 9ms/step
# Epoch 341/400
# 50/50 - 0s - loss: 0.1670 - acc: 0.9439 - 400ms/epoch - 8ms/step
# Epoch 342/400
# 50/50 - 0s - loss: 0.0986 - acc: 0.9750 - 386ms/epoch - 8ms/step
# Epoch 343/400
# 50/50 - 0s - loss: 0.0826 - acc: 0.9720 - 379ms/epoch - 8ms/step
# Epoch 344/400
# 50/50 - 0s - loss: 0.0802 - acc: 0.9840 - 407ms/epoch - 8ms/step
# Epoch 345/400
# 50/50 - 0s - loss: 0.0684 - acc: 0.9870 - 369ms/epoch - 7ms/step
# Epoch 346/400
# 50/50 - 0s - loss: 0.0544 - acc: 0.9870 - 393ms/epoch - 8ms/step
# Epoch 347/400
# 50/50 - 0s - loss: 0.0814 - acc: 0.9780 - 405ms/epoch - 8ms/step
# Epoch 348/400
# 50/50 - 0s - loss: 0.1093 - acc: 0.9690 - 399ms/epoch - 8ms/step
# Epoch 349/400
# 50/50 - 0s - loss: 0.1461 - acc: 0.9489 - 361ms/epoch - 7ms/step
# Epoch 350/400
# 50/50 - 0s - loss: 0.2296 - acc: 0.9329 - 382ms/epoch - 8ms/step
# Epoch 351/400
# 50/50 - 0s - loss: 0.1989 - acc: 0.9349 - 373ms/epoch - 7ms/step
# Epoch 352/400
# 50/50 - 0s - loss: 0.1258 - acc: 0.9580 - 397ms/epoch - 8ms/step
# Epoch 353/400
# 50/50 - 0s - loss: 0.1047 - acc: 0.9710 - 371ms/epoch - 7ms/step
# Epoch 354/400
# 50/50 - 0s - loss: 0.1583 - acc: 0.9449 - 382ms/epoch - 8ms/step
# Epoch 355/400
# 50/50 - 0s - loss: 0.1165 - acc: 0.9650 - 375ms/epoch - 8ms/step
# Epoch 356/400
# 50/50 - 0s - loss: 0.1376 - acc: 0.9590 - 403ms/epoch - 8ms/step
# Epoch 357/400
# 50/50 - 0s - loss: 0.2439 - acc: 0.9159 - 408ms/epoch - 8ms/step
# Epoch 358/400
# 50/50 - 0s - loss: 0.1757 - acc: 0.9469 - 389ms/epoch - 8ms/step
# Epoch 359/400
# 50/50 - 0s - loss: 0.1205 - acc: 0.9640 - 394ms/epoch - 8ms/step
# Epoch 360/400
# 50/50 - 0s - loss: 0.0638 - acc: 0.9840 - 361ms/epoch - 7ms/step
# Epoch 361/400
# 50/50 - 0s - loss: 0.0609 - acc: 0.9830 - 381ms/epoch - 8ms/step
# Epoch 362/400
# 50/50 - 0s - loss: 0.0519 - acc: 0.9910 - 375ms/epoch - 8ms/step
# Epoch 363/400
# 50/50 - 0s - loss: 0.0610 - acc: 0.9860 - 388ms/epoch - 8ms/step
# Epoch 364/400
# 50/50 - 0s - loss: 0.0648 - acc: 0.9860 - 385ms/epoch - 8ms/step
# Epoch 365/400
# 50/50 - 0s - loss: 0.0884 - acc: 0.9710 - 382ms/epoch - 8ms/step
# Epoch 366/400
# 50/50 - 0s - loss: 0.0448 - acc: 0.9900 - 372ms/epoch - 7ms/step
# Epoch 367/400
# 50/50 - 0s - loss: 0.0851 - acc: 0.9740 - 373ms/epoch - 7ms/step
# Epoch 368/400
# 50/50 - 0s - loss: 0.1657 - acc: 0.9449 - 417ms/epoch - 8ms/step
# Epoch 369/400
# 50/50 - 0s - loss: 0.1209 - acc: 0.9670 - 429ms/epoch - 9ms/step
# Epoch 370/400
# 50/50 - 0s - loss: 0.3590 - acc: 0.9089 - 376ms/epoch - 8ms/step
# Epoch 371/400
# 50/50 - 0s - loss: 0.7072 - acc: 0.7568 - 369ms/epoch - 7ms/step
# Epoch 372/400
# 50/50 - 0s - loss: 0.2663 - acc: 0.9089 - 417ms/epoch - 8ms/step
# Epoch 373/400
# 50/50 - 0s - loss: 0.1789 - acc: 0.9399 - 404ms/epoch - 8ms/step
# Epoch 374/400
# 50/50 - 0s - loss: 0.1236 - acc: 0.9680 - 382ms/epoch - 8ms/step
# Epoch 375/400
# 50/50 - 0s - loss: 0.1350 - acc: 0.9580 - 393ms/epoch - 8ms/step
# Epoch 376/400
# 50/50 - 0s - loss: 0.1895 - acc: 0.9369 - 424ms/epoch - 8ms/step
# Epoch 377/400
# 50/50 - 0s - loss: 0.1231 - acc: 0.9660 - 373ms/epoch - 7ms/step
# Epoch 378/400
# 50/50 - 0s - loss: 0.0713 - acc: 0.9860 - 385ms/epoch - 8ms/step
# Epoch 379/400
# 50/50 - 0s - loss: 0.0475 - acc: 0.9900 - 418ms/epoch - 8ms/step
# Epoch 380/400
# 50/50 - 0s - loss: 0.0543 - acc: 0.9860 - 411ms/epoch - 8ms/step
# Epoch 381/400
# 50/50 - 0s - loss: 0.0434 - acc: 0.9910 - 355ms/epoch - 7ms/step
# Epoch 382/400
# 50/50 - 0s - loss: 0.0290 - acc: 0.9950 - 357ms/epoch - 7ms/step
# Epoch 383/400
# 50/50 - 0s - loss: 0.0282 - acc: 0.9970 - 383ms/epoch - 8ms/step
# Epoch 384/400
# 50/50 - 0s - loss: 0.0366 - acc: 0.9920 - 336ms/epoch - 7ms/step
# Epoch 385/400
# 50/50 - 0s - loss: 0.0830 - acc: 0.9800 - 368ms/epoch - 7ms/step
# Epoch 386/400
# 50/50 - 0s - loss: 0.0883 - acc: 0.9770 - 394ms/epoch - 8ms/step
# Epoch 387/400
# 50/50 - 0s - loss: 0.1881 - acc: 0.9429 - 411ms/epoch - 8ms/step
# Epoch 388/400
# 50/50 - 0s - loss: 0.2018 - acc: 0.9269 - 399ms/epoch - 8ms/step
# Epoch 389/400
# 50/50 - 0s - loss: 0.1352 - acc: 0.9550 - 388ms/epoch - 8ms/step
# Epoch 390/400
# 50/50 - 0s - loss: 0.1047 - acc: 0.9690 - 351ms/epoch - 7ms/step
# Epoch 391/400
# 50/50 - 0s - loss: 0.0951 - acc: 0.9740 - 357ms/epoch - 7ms/step
# Epoch 392/400
# 50/50 - 0s - loss: 0.1557 - acc: 0.9489 - 377ms/epoch - 8ms/step
# Epoch 393/400
# 50/50 - 0s - loss: 0.1787 - acc: 0.9429 - 364ms/epoch - 7ms/step
# Epoch 394/400
# 50/50 - 0s - loss: 0.1462 - acc: 0.9540 - 431ms/epoch - 9ms/step
# Epoch 395/400
# 50/50 - 0s - loss: 0.2435 - acc: 0.9159 - 384ms/epoch - 8ms/step
# Epoch 396/400
# 50/50 - 0s - loss: 0.1228 - acc: 0.9660 - 407ms/epoch - 8ms/step
# Epoch 397/400
# 50/50 - 0s - loss: 0.1154 - acc: 0.9630 - 412ms/epoch - 8ms/step
# Epoch 398/400
# 50/50 - 0s - loss: 0.0788 - acc: 0.9780 - 367ms/epoch - 7ms/step
# Epoch 399/400
# 50/50 - 0s - loss: 0.0430 - acc: 0.9910 - 359ms/epoch - 7ms/step
# Epoch 400/400
# 50/50 - 0s - loss: 0.0298 - acc: 0.9950 - 407ms/epoch - 8ms/step
# Found 999 images belonging to 10 classes.
# Epoch 1/50
# 50/50 - 5s - loss: 2.4231 - acc: 0.1301 - 5s/epoch - 103ms/step
# Epoch 2/50
# 50/50 - 1s - loss: 2.1990 - acc: 0.2042 - 1s/epoch - 26ms/step
# Epoch 3/50
# 50/50 - 1s - loss: 1.9890 - acc: 0.2613 - 1s/epoch - 26ms/step
# Epoch 4/50
# 50/50 - 1s - loss: 1.8838 - acc: 0.3023 - 1s/epoch - 26ms/step
# Epoch 5/50
# 50/50 - 1s - loss: 1.8175 - acc: 0.3223 - 1s/epoch - 26ms/step
# Epoch 6/50
# 50/50 - 1s - loss: 1.7489 - acc: 0.3403 - 1s/epoch - 26ms/step
# Epoch 7/50
# 50/50 - 1s - loss: 1.6801 - acc: 0.3584 - 1s/epoch - 27ms/step
# Epoch 8/50
# 50/50 - 1s - loss: 1.6258 - acc: 0.3894 - 1s/epoch - 26ms/step
# Epoch 9/50
# 50/50 - 1s - loss: 1.6036 - acc: 0.4084 - 1s/epoch - 27ms/step
# Epoch 10/50
# 50/50 - 1s - loss: 1.5578 - acc: 0.4324 - 1s/epoch - 26ms/step
# Epoch 11/50
# 50/50 - 1s - loss: 1.5247 - acc: 0.4324 - 1s/epoch - 26ms/step
# Epoch 12/50
# 50/50 - 1s - loss: 1.4398 - acc: 0.4825 - 1s/epoch - 26ms/step
# Epoch 13/50
# 50/50 - 1s - loss: 1.4385 - acc: 0.4715 - 1s/epoch - 26ms/step
# Epoch 14/50
# 50/50 - 1s - loss: 1.3979 - acc: 0.4785 - 1s/epoch - 26ms/step
# Epoch 15/50
# 50/50 - 1s - loss: 1.3941 - acc: 0.4935 - 1s/epoch - 26ms/step
# Epoch 16/50
# 50/50 - 1s - loss: 1.3171 - acc: 0.5165 - 1s/epoch - 26ms/step
# Epoch 17/50
# 50/50 - 1s - loss: 1.3146 - acc: 0.5155 - 1s/epoch - 26ms/step
# Epoch 18/50
# 50/50 - 1s - loss: 1.2326 - acc: 0.5335 - 1s/epoch - 26ms/step
# Epoch 19/50
# 50/50 - 1s - loss: 1.2106 - acc: 0.5465 - 1s/epoch - 26ms/step
# Epoch 20/50
# 50/50 - 1s - loss: 1.1520 - acc: 0.5966 - 1s/epoch - 26ms/step
# Epoch 21/50
# 50/50 - 1s - loss: 1.0990 - acc: 0.6006 - 1s/epoch - 26ms/step
# Epoch 22/50
# 50/50 - 1s - loss: 1.0578 - acc: 0.6216 - 1s/epoch - 26ms/step
# Epoch 23/50
# 50/50 - 1s - loss: 1.0691 - acc: 0.6026 - 1s/epoch - 26ms/step
# Epoch 24/50
# 50/50 - 1s - loss: 1.0264 - acc: 0.6296 - 1s/epoch - 26ms/step
# Epoch 25/50
# 50/50 - 1s - loss: 0.9803 - acc: 0.6426 - 1s/epoch - 26ms/step
# Epoch 26/50
# 50/50 - 1s - loss: 0.9501 - acc: 0.6717 - 1s/epoch - 27ms/step
# Epoch 27/50
# 50/50 - 1s - loss: 0.9186 - acc: 0.6787 - 1s/epoch - 26ms/step
# Epoch 28/50
# 50/50 - 1s - loss: 0.8447 - acc: 0.7027 - 1s/epoch - 26ms/step
# Epoch 29/50
# 50/50 - 1s - loss: 0.8691 - acc: 0.6947 - 1s/epoch - 26ms/step
# Epoch 30/50
# 50/50 - 1s - loss: 0.8126 - acc: 0.7077 - 1s/epoch - 26ms/step
# Epoch 31/50
# 50/50 - 1s - loss: 0.7835 - acc: 0.7207 - 1s/epoch - 27ms/step
# Epoch 32/50
# 50/50 - 1s - loss: 0.7150 - acc: 0.7467 - 1s/epoch - 27ms/step
# Epoch 33/50
# 50/50 - 1s - loss: 0.6389 - acc: 0.7978 - 1s/epoch - 27ms/step
# Epoch 34/50
# 50/50 - 1s - loss: 0.6306 - acc: 0.7868 - 1s/epoch - 26ms/step
# Epoch 35/50
# 50/50 - 1s - loss: 0.6015 - acc: 0.7998 - 1s/epoch - 26ms/step
# Epoch 36/50
# 50/50 - 1s - loss: 0.5369 - acc: 0.8368 - 1s/epoch - 27ms/step
# Epoch 37/50
# 50/50 - 1s - loss: 0.4941 - acc: 0.8468 - 1s/epoch - 27ms/step
# Epoch 38/50
# 50/50 - 1s - loss: 0.4301 - acc: 0.8769 - 1s/epoch - 26ms/step
# Epoch 39/50
# 50/50 - 1s - loss: 0.4220 - acc: 0.8729 - 1s/epoch - 26ms/step
# Epoch 40/50
# 50/50 - 1s - loss: 0.3676 - acc: 0.8869 - 1s/epoch - 26ms/step
# Epoch 41/50
# 50/50 - 1s - loss: 0.3799 - acc: 0.8869 - 1s/epoch - 26ms/step
# Epoch 42/50
# 50/50 - 1s - loss: 0.3177 - acc: 0.8989 - 1s/epoch - 27ms/step
# Epoch 43/50
# 50/50 - 1s - loss: 0.3063 - acc: 0.9209 - 1s/epoch - 27ms/step
# Epoch 44/50
# 50/50 - 1s - loss: 0.2746 - acc: 0.9279 - 1s/epoch - 27ms/step
# Epoch 45/50
# 50/50 - 1s - loss: 0.2055 - acc: 0.9449 - 1s/epoch - 26ms/step
# Epoch 46/50
# 50/50 - 1s - loss: 0.1726 - acc: 0.9640 - 1s/epoch - 26ms/step
# Epoch 47/50
# 50/50 - 1s - loss: 0.1945 - acc: 0.9489 - 1s/epoch - 27ms/step
# Epoch 48/50
# 50/50 - 1s - loss: 0.1436 - acc: 0.9750 - 1s/epoch - 26ms/step
# Epoch 49/50
# 50/50 - 1s - loss: 0.1224 - acc: 0.9780 - 1s/epoch - 26ms/step
# Epoch 50/50
# 50/50 - 1s - loss: 0.1218 - acc: 0.9750 - 1s/epoch - 26ms/step
# Found 999 images belonging to 10 classes.
# Epoch 1/10
# 2024-01-28 15:50:35.129884: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_1/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 50/50 - 2s - loss: 2.4612 - acc: 0.1502 - 2s/epoch - 36ms/step
# Epoch 2/10
# 50/50 - 0s - loss: 2.0113 - acc: 0.2743 - 280ms/epoch - 6ms/step
# Epoch 3/10
# 50/50 - 0s - loss: 1.7155 - acc: 0.3884 - 289ms/epoch - 6ms/step
# Epoch 4/10
# 50/50 - 0s - loss: 1.3808 - acc: 0.5265 - 293ms/epoch - 6ms/step
# Epoch 5/10
# 50/50 - 0s - loss: 1.0719 - acc: 0.6597 - 312ms/epoch - 6ms/step
# Epoch 6/10
# 50/50 - 0s - loss: 0.7818 - acc: 0.7768 - 282ms/epoch - 6ms/step
# Epoch 7/10
# 50/50 - 0s - loss: 0.5342 - acc: 0.8679 - 303ms/epoch - 6ms/step
# Epoch 8/10
# 50/50 - 0s - loss: 0.3189 - acc: 0.9469 - 279ms/epoch - 6ms/step
# Epoch 9/10
# 50/50 - 0s - loss: 0.2207 - acc: 0.9750 - 291ms/epoch - 6ms/step
# Epoch 10/10
# 50/50 - 0s - loss: 0.1441 - acc: 0.9910 - 278ms/epoch - 6ms/step

# %%
model_mel.save_model("./model/model_mel.h5")
model_chr.save_model("./model/model_chr.h5")
model_mfcc.save_model("./model/model_mfcc.h5")

# %%
model_mel.load_model("./model/model_mel.h5")
model_chr.load_model("./model/model_chr.h5")
model_mfcc.load_model("./model/model_mfcc.h5")

# %%
from NeuralNetwork.combine_model import CombineModel
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
combine_model = CombineModel(input_dim=30)
combine_model.train("/home/lumiani/Projects/IML/CS182-FinalProject/dataset/merge_format", epoch=40)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 30, 32)            128
#
#  conv1d_1 (Conv1D)           (None, 30, 64)            6208
#
#  conv1d_2 (Conv1D)           (None, 30, 128)           24704
#
#  conv1d_3 (Conv1D)           (None, 30, 256)           98560
#
#  conv1d_4 (Conv1D)           (None, 30, 512)           393728
#
#  conv1d_5 (Conv1D)           (None, 30, 1024)          1573888
#
#  conv1d_6 (Conv1D)           (None, 30, 2048)          6293504
#
#  conv1d_7 (Conv1D)           (None, 30, 4096)          25169920
#
#  conv1d_8 (Conv1D)           (None, 30, 8192)          100671488
#
#  flatten_3 (Flatten)         (None, 245760)            0
#
#  batch_normalization_2 (Bat  (None, 245760)            983040
#  chNormalization)
#
#  dense_9 (Dense)             (None, 10)                2457610
#
# =================================================================
# Total params: 137672778 (525.18 MB)
# Trainable params: 137181258 (523.30 MB)
# Non-trainable params: 491520 (1.88 MB)
# _________________________________________________________________
# None
# Epoch 1/40
# 50/50 [==============================] - 5s 38ms/step - loss: 2.3009 - acc: 0.0990
# Epoch 2/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.3012 - acc: 0.1180
# Epoch 3/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2997 - acc: 0.1130
# Epoch 4/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2915 - acc: 0.1250
# Epoch 5/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2867 - acc: 0.1380
# Epoch 6/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2872 - acc: 0.1300
# Epoch 7/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2888 - acc: 0.1420
# Epoch 8/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2891 - acc: 0.1290
# Epoch 9/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2824 - acc: 0.1270
# Epoch 10/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2658 - acc: 0.1640
# Epoch 11/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2783 - acc: 0.1330
# Epoch 12/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2677 - acc: 0.1370
# Epoch 13/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2677 - acc: 0.1430
# Epoch 14/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2502 - acc: 0.1510
# Epoch 15/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2515 - acc: 0.1580
# Epoch 16/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2539 - acc: 0.1660
# Epoch 17/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2535 - acc: 0.1470
# Epoch 18/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2499 - acc: 0.1580
# Epoch 19/40
# 50/50 [==============================] - 2s 38ms/step - loss: 2.2277 - acc: 0.1930
# Epoch 20/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2260 - acc: 0.1680
# Epoch 21/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2264 - acc: 0.1670
# Epoch 22/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2361 - acc: 0.1520
# Epoch 23/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2274 - acc: 0.1710
# Epoch 24/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2326 - acc: 0.1690
# Epoch 25/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2197 - acc: 0.1530
# Epoch 26/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2068 - acc: 0.1790
# Epoch 27/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.2094 - acc: 0.1730
# Epoch 28/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2096 - acc: 0.1750
# Epoch 29/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2061 - acc: 0.1770
# Epoch 30/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2156 - acc: 0.1900
# Epoch 31/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.1924 - acc: 0.1880
# Epoch 32/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.1926 - acc: 0.1910
# Epoch 33/40
# 50/50 [==============================] - 2s 35ms/step - loss: 2.1725 - acc: 0.2070
# Epoch 34/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.1786 - acc: 0.2010
# Epoch 35/40
# 50/50 [==============================] - 2s 37ms/step - loss: 2.1746 - acc: 0.1860
# Epoch 36/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.2009 - acc: 0.1860
# Epoch 37/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.1538 - acc: 0.2280
# Epoch 38/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.1949 - acc: 0.1880
# Epoch 39/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.1741 - acc: 0.2130
# Epoch 40/40
# 50/50 [==============================] - 2s 36ms/step - loss: 2.1704 - acc: 0.1890

# %%
import numpy as np
import librosa

# y, sr = librosa.load("./dataset/test_long/On Va S'aimer Encore.mp3")
# y,  sr = librosa.load("./dataset/test_long/DSM-V.mp3")
# y, sr = librosa.load("./dataset/test_long/许巍 - 蓝莲花.mp3")
# y, sr = librosa.load("./dataset/test_long/Charlie Puth - See You Again.mp3")
# y, sr = librosa.load("./dataset/audio_format/pop/pop.00011.wav")
# y, sr = librosa.load("./dataset/test_long/killing in the name.mp3")
# y, sr = librosa.load("./dataset/test_long/deemo-good-bye.mp3")
# y, sr = librosa.load("dataset/test_long/拉德斯基进..._lan.flac")
# y, sr = librosa.load("dataset/test_long/悲怆 第三章.flac")
# y, sr = librosa.load("dataset/test_long/Bad Apple-のみこ,Masayoshi Minoshima.flac")
# y, sr = librosa.load("dataset/test_long/pf.mp3")
y, sr = librosa.load("dataset/test_long/pfffff.mp3")
# y, sr = librosa.load("")


spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)

mel_pic = librosa.power_to_db(spectrogram, ref=np.max)

harmonic = librosa.effects.harmonic(y)  ##
harmonic_features = librosa.feature.chroma_cqt(y=harmonic, sr=sr)  ##

mfccs = librosa.feature.mfcc(y=y, sr=sr)

duration = len(y) / sr



# Assuming model1, model2, model3 are already defined with different input shapes but the same output shape

_, pre_mel = model_mel.predict(mel_pic, duration)
_, pre_chr = model_chr.predict(harmonic_features, duration)
_, pre_mfcc = model_mfcc.predict(mfccs, duration)


pre_mel=pre_mel.flatten()
pre_chr=pre_chr.flatten()
pre_mfcc=pre_mfcc.flatten()

#xpj add:
merge_array=[]
for arr in [pre_mel, pre_chr, pre_mfcc]:
    merge_array.extend(arr)
merge_array=np.expand_dims(merge_array, axis=0)
# for i in range (10):
#     merge_array.append(pre_mel[i])
#     merge_array.append(pre_chr[i])
#     merge_array.append(pre_mfcc[i])
# merge_array=np.asarray(merge_array)
# print(merge_array.shape)
pre = combine_model.model.predict(merge_array)
print(pre)
class_idx = np.argmax(pre, axis=1)[0]
print(["pop", "classical", "pop", "rock", "pop", "jazz", "rock", "pop", "pop", "rock"][class_idx])
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# [[0.11652709 0.45976484 0.05051478 0.01902571 0.15734376 0.07543361
#   0.02878115 0.00970437 0.06292645 0.0199783 ]]
# classical

# %%
import os
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

def read_array_from_txt(input_path):
        try:
            array_data = np.loadtxt(input_path)
            return array_data.reshape(1, -1)  # 将数据 reshape 成 (1, 30)
        except Exception as e:
            print(f"Error reading array from {input_path}: {e}")
            return None

# 定义全连接层模型
def create_fc_model(input_dim=30, output_dim=10):  # 根据你的实际情况设置 output_dim
    model = Sequential()
    model.add(Dense(units=128, input_dim=input_dim, activation='relu'))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=output_dim, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

input_data_path = "/home/lumiani/Projects/IML/CS182-FinalProject/dataset/merge_format/blues/blues.00000.txt"
model_output_dim = 10

# 读取数组数据
array_data = read_array_from_txt(input_data_path)
print(array_data)

# 如果成功读取数据，则使用全连接层模型进行训练
if array_data is not None:
    # 创建全连接层模型
    model = create_fc_model(input_dim=array_data.shape[1], output_dim=model_output_dim)

    target_data = np.random.rand(1, model_output_dim)

    # 训练模型
    model.fit(array_data, target_data, epochs=10, batch_size=1)
else:
    print("Error: Unable to proceed with training due to missing array data.")
# Out:
# [[6.14888817e-02 8.22709724e-02 2.80159861e-02 7.99708739e-02
#   1.31799832e-01 1.26253545e-01 6.77800402e-02 6.19016588e-02
#   2.61953861e-01 9.85643789e-02 1.68461666e-01 8.22714046e-02
#   1.12947278e-01 2.60181352e-02 3.14562693e-02 4.89889562e-01
#   1.06522767e-02 1.90252736e-02 4.12968695e-02 1.79812200e-02
#   4.71478654e-03 6.70126392e-05 4.95133549e-01 4.11524717e-03
#   1.27814978e-03 3.63514014e-03 5.51041495e-03 8.26615491e-04
#   3.95665271e-03 4.80762452e-01]]
# Epoch 1/10
# 1/1 [==============================] - 0s 396ms/step - loss: 11.6944 - accuracy: 0.0000e+00
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.6664 - accuracy: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.6405 - accuracy: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.6150 - accuracy: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5899 - accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5669 - accuracy: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5441 - accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5235 - accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5035 - accuracy: 0.0000e+00
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.4834 - accuracy: 0.0000e+00

# %%
import librosa

# 加载音频文件
audio_file = './dataset/audio_format/blues/blues.00000.wav'  # 替换为您的音频文件路径
y, sr = librosa.load(audio_file)

# 1. 音高和旋律特征
chroma = librosa.feature.chroma_cqt(y=y, sr=sr)

# 2. 节奏和节拍
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
beat_times = librosa.frames_to_time(beat_frames, sr=sr)

# 3. 和声和和弦结构
harmonic = librosa.effects.harmonic(y)
harmonic_features = librosa.feature.chroma_cqt(y=harmonic, sr=sr)

# 4. 音色和乐器使用
mfccs = librosa.feature.mfcc(y=y, sr=sr)

# 5. 动态范围和强度
S, phase = librosa.magphase(librosa.stft(y))
rms = librosa.feature.rms(S=S)

# 6. 时间结构和形式
temporal_onset = librosa.onset.onset_strength(y=y, sr=sr)

# 7. 时域特征
zero_crossing_rate = librosa.feature.zero_crossing_rate(y)

# 输出每个特征的shape
print("Chroma (Pitch):", chroma.shape)
print("Tempo (Rhythm):", beat_times.shape)
print("Harmonic Features (Harmony):", harmonic_features.shape)
print("MFCCs (Timbre):", mfccs.shape)
print("RMS (Dynamics):", rms.shape)
print("Temporal Onset (Form):", temporal_onset.shape)
print("Zero Crossing Rate (Time-domain):", zero_crossing_rate.shape)
# Out:
# Chroma (Pitch): (12, 1293)
# Tempo (Rhythm): (61,)
# Harmonic Features (Harmony): (12, 1293)
# MFCCs (Timbre): (20, 1293)
# RMS (Dynamics): (1, 1293)
# Temporal Onset (Form): (1293,)
# Zero Crossing Rate (Time-domain): (1, 1293)
